# %% [markdown]
# # Function Calling
#
# **Function calling** é, de fato, uma estratégia de fornecer ao LLM um “esqueleto” estruturado (normalmente em JSON Schema) descrevendo:
#
# - Nome da função
# - O que ela faz
# - Quais argumentos aceita
# - Tipo/formato desses argumentos
# - Quais campos são obrigatórios
#
# Isso guia o modelo a:
# - Entender quando usar a função
# - Como montar corretamente os argumentos
# - Devolver uma saída estruturada e válida, reduzindo erros
#
# Ou seja: não é para o LLM executar a função, e sim para pedir corretamente que ela seja executada pelo seu código.

# %%
import os, json
from dotenv import dotenv_values
import requests
from openai import OpenAI

config = dotenv_values("../.env")
openai_api_key = config["OPENAI_API_KEY"]
open_weather_key = config["OPEN_WEATHER"]

# %% [markdown]
# ## Testando API Open Weather

# %%
lat = -4.35795
lon = -39.3024
url = (
    f"https://api.openweathermap.org/data/3.0/onecall"
    f"?lat={lat}&lon={lon}"
    f"&appid={open_weather_key}"
    f"&units=metric&lang=pt_br"
) 


resp = requests.get(url)  
resp.status_code
# Out:
# 200

# %%
result = json.loads(resp.content)
result
# Out:
# {'lat': -4.358,
#  'lon': -39.3024,
#  'timezone': 'America/Fortaleza',
#  'timezone_offset': -10800,
#  'current': {'dt': 1769033264,
#   'sunrise': 1768984707,
#   'sunset': 1769029091,
#   'temp': 27.27,
#   'feels_like': 28.19,
#   'pressure': 1009,
#   'humidity': 57,
#   'dew_point': 18.01,
#   'uvi': 0,
#   'clouds': 54,
#   'visibility': 10000,
#   'wind_speed': 2.36,
#   'wind_deg': 64,
#   'wind_gust': 5.38,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'nublado',
#     'icon': '04n'}]},
#  'minutely': [{'dt': 1769033280, 'precipitation': 0},
#   {'dt': 1769033340, 'precipitation': 0},
#   {'dt': 1769033400, 'precipitation': 0},
#   {'dt': 1769033460, 'precipitation': 0},
#   {'dt': 1769033520, 'precipitation': 0},
#   {'dt': 1769033580, 'precipitation': 0},
#   {'dt': 1769033640, 'precipitation': 0},
#   {'dt': 1769033700, 'precipitation': 0},
#   {'dt': 1769033760, 'precipitation': 0},
#   {'dt': 1769033820, 'precipitation': 0},
#   {'dt': 1769033880, 'precipitation': 0},
#   {'dt': 1769033940, 'precipitation': 0},
#   {'dt': 1769034000, 'precipitation': 0},
#   {'dt': 1769034060, 'precipitation': 0},
#   {'dt': 1769034120, 'precipitation': 0},
#   {'dt': 1769034180, 'precipitation': 0},
#   {'dt': 1769034240, 'precipitation': 0},
#   {'dt': 1769034300, 'precipitation': 0},
#   {'dt': 1769034360, 'precipitation': 0},
#   {'dt': 1769034420, 'precipitation': 0},
#   {'dt': 1769034480, 'precipitation': 0},
#   {'dt': 1769034540, 'precipitation': 0},
#   {'dt': 1769034600, 'precipitation': 0},
#   {'dt': 1769034660, 'precipitation': 0},
#   {'dt': 1769034720, 'precipitation': 0},
#   {'dt': 1769034780, 'precipitation': 0},
#   {'dt': 1769034840, 'precipitation': 0},
#   {'dt': 1769034900, 'precipitation': 0},
#   {'dt': 1769034960, 'precipitation': 0},
#   {'dt': 1769035020, 'precipitation': 0},
#   {'dt': 1769035080, 'precipitation': 0},
#   {'dt': 1769035140, 'precipitation': 0},
#   {'dt': 1769035200, 'precipitation': 0},
#   {'dt': 1769035260, 'precipitation': 0},
#   {'dt': 1769035320, 'precipitation': 0},
#   {'dt': 1769035380, 'precipitation': 0},
#   {'dt': 1769035440, 'precipitation': 0},
#   {'dt': 1769035500, 'precipitation': 0},
#   {'dt': 1769035560, 'precipitation': 0},
#   {'dt': 1769035620, 'precipitation': 0},
#   {'dt': 1769035680, 'precipitation': 0},
#   {'dt': 1769035740, 'precipitation': 0},
#   {'dt': 1769035800, 'precipitation': 0},
#   {'dt': 1769035860, 'precipitation': 0},
#   {'dt': 1769035920, 'precipitation': 0},
#   {'dt': 1769035980, 'precipitation': 0},
#   {'dt': 1769036040, 'precipitation': 0},
#   {'dt': 1769036100, 'precipitation': 0},
#   {'dt': 1769036160, 'precipitation': 0},
#   {'dt': 1769036220, 'precipitation': 0},
#   {'dt': 1769036280, 'precipitation': 0},
#   {'dt': 1769036340, 'precipitation': 0},
#   {'dt': 1769036400, 'precipitation': 0},
#   {'dt': 1769036460, 'precipitation': 0},
#   {'dt': 1769036520, 'precipitation': 0},
#   {'dt': 1769036580, 'precipitation': 0},
#   {'dt': 1769036640, 'precipitation': 0},
#   {'dt': 1769036700, 'precipitation': 0},
#   {'dt': 1769036760, 'precipitation': 0},
#   {'dt': 1769036820, 'precipitation': 0}],
#  'hourly': [{'dt': 1769032800,
#    'temp': 27.27,
#    'feels_like': 28.19,
#    'pressure': 1009,
#    'humidity': 57,
#    'dew_point': 18.01,
#    'uvi': 0,
#    'clouds': 54,
#    'visibility': 10000,
#    'wind_speed': 2.36,
#    'wind_deg': 64,
#    'wind_gust': 5.38,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769036400,
#    'temp': 27.09,
#    'feels_like': 28.12,
#    'pressure': 1009,
#    'humidity': 59,
#    'dew_point': 18.39,
#    'uvi': 0,
#    'clouds': 53,
#    'visibility': 10000,
#    'wind_speed': 1.25,
#    'wind_deg': 64,
#    'wind_gust': 3.26,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769040000,
#    'temp': 26.52,
#    'feels_like': 26.52,
#    'pressure': 1010,
#    'humidity': 63,
#    'dew_point': 18.91,
#    'uvi': 0,
#    'clouds': 48,
#    'visibility': 10000,
#    'wind_speed': 0.34,
#    'wind_deg': 17,
#    'wind_gust': 1.37,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769043600,
#    'temp': 25.88,
#    'feels_like': 26.33,
#    'pressure': 1010,
#    'humidity': 69,
#    'dew_point': 19.76,
#    'uvi': 0,
#    'clouds': 70,
#    'visibility': 10000,
#    'wind_speed': 0.38,
#    'wind_deg': 355,
#    'wind_gust': 0,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769047200,
#    'temp': 25.03,
#    'feels_like': 25.6,
#    'pressure': 1011,
#    'humidity': 77,
#    'dew_point': 20.72,
#    'uvi': 0,
#    'clouds': 50,
#    'visibility': 10000,
#    'wind_speed': 0.64,
#    'wind_deg': 313,
#    'wind_gust': 0,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769050800,
#    'temp': 24.41,
#    'feels_like': 25.13,
#    'pressure': 1011,
#    'humidity': 85,
#    'dew_point': 19.78,
#    'uvi': 0,
#    'clouds': 48,
#    'visibility': 10000,
#    'wind_speed': 0.19,
#    'wind_deg': 102,
#    'wind_gust': 0,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769054400,
#    'temp': 23.8,
#    'feels_like': 24.51,
#    'pressure': 1011,
#    'humidity': 87,
#    'dew_point': 19.81,
#    'uvi': 0,
#    'clouds': 48,
#    'visibility': 10000,
#    'wind_speed': 0.35,
#    'wind_deg': 187,
#    'wind_gust': 0,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769058000,
#    'temp': 23.6,
#    'feels_like': 24.31,
#    'pressure': 1010,
#    'humidity': 88,
#    'dew_point': 19.69,
#    'uvi': 0,
#    'clouds': 40,
#    'visibility': 10000,
#    'wind_speed': 0.56,
#    'wind_deg': 219,
#    'wind_gust': 0,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769061600,
#    'temp': 23.33,
#    'feels_like': 24.07,
#    'pressure': 1010,
#    'humidity': 90,
#    'dew_point': 19.62,
#    'uvi': 0,
#    'clouds': 35,
#    'visibility': 10000,
#    'wind_speed': 1.16,
#    'wind_deg': 195,
#    'wind_gust': 0.56,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769065200,
#    'temp': 23.01,
#    'feels_like': 23.74,
#    'pressure': 1010,
#    'humidity': 91,
#    'dew_point': 19.7,
#    'uvi': 0,
#    'clouds': 1,
#    'visibility': 10000,
#    'wind_speed': 1.56,
#    'wind_deg': 178,
#    'wind_gust': 1,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1769068800,
#    'temp': 22.21,
#    'feels_like': 22.91,
#    'pressure': 1011,
#    'humidity': 93,
#    'dew_point': 19.94,
#    'uvi': 0,
#    'clouds': 5,
#    'visibility': 10000,
#    'wind_speed': 1.51,
#    'wind_deg': 170,
#    'wind_gust': 1.04,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'céu limpo',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1769072400,
#    'temp': 22.38,
#    'feels_like': 23.13,
#    'pressure': 1011,
#    'humidity': 94,
#    'dew_point': 20.22,
#    'uvi': 0.16,
#    'clouds': 19,
#    'visibility': 10000,
#    'wind_speed': 1.47,
#    'wind_deg': 161,
#    'wind_gust': 2.15,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'algumas nuvens',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1769076000,
#    'temp': 24.93,
#    'feels_like': 25.46,
#    'pressure': 1012,
#    'humidity': 76,
#    'dew_point': 20.23,
#    'uvi': 0.74,
#    'clouds': 25,
#    'visibility': 10000,
#    'wind_speed': 1.68,
#    'wind_deg': 129,
#    'wind_gust': 4.1,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769079600,
#    'temp': 27.75,
#    'feels_like': 28.89,
#    'pressure': 1012,
#    'humidity': 58,
#    'dew_point': 19.11,
#    'uvi': 2.99,
#    'clouds': 24,
#    'visibility': 10000,
#    'wind_speed': 2.59,
#    'wind_deg': 108,
#    'wind_gust': 5.18,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'algumas nuvens',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1769083200,
#    'temp': 30.34,
#    'feels_like': 31.07,
#    'pressure': 1012,
#    'humidity': 47,
#    'dew_point': 17.92,
#    'uvi': 6.41,
#    'clouds': 24,
#    'visibility': 10000,
#    'wind_speed': 3.45,
#    'wind_deg': 105,
#    'wind_gust': 5.66,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'algumas nuvens',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1769086800,
#    'temp': 32.2,
#    'feels_like': 32.57,
#    'pressure': 1012,
#    'humidity': 40,
#    'dew_point': 17.06,
#    'uvi': 10.61,
#    'clouds': 50,
#    'visibility': 10000,
#    'wind_speed': 3.92,
#    'wind_deg': 107,
#    'wind_gust': 5.64,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769090400,
#    'temp': 34.06,
#    'feels_like': 34.13,
#    'pressure': 1010,
#    'humidity': 34,
#    'dew_point': 15.95,
#    'uvi': 12.9,
#    'clouds': 69,
#    'visibility': 10000,
#    'wind_speed': 4.27,
#    'wind_deg': 110,
#    'wind_gust': 5.82,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769094000,
#    'temp': 35.75,
#    'feels_like': 35.32,
#    'pressure': 1009,
#    'humidity': 28,
#    'dew_point': 14.77,
#    'uvi': 13.22,
#    'clouds': 69,
#    'visibility': 10000,
#    'wind_speed': 3.96,
#    'wind_deg': 110,
#    'wind_gust': 5.3,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769097600,
#    'temp': 36.77,
#    'feels_like': 36.34,
#    'pressure': 1008,
#    'humidity': 26,
#    'dew_point': 13.94,
#    'uvi': 11.44,
#    'clouds': 73,
#    'visibility': 10000,
#    'wind_speed': 3.88,
#    'wind_deg': 110,
#    'wind_gust': 4.94,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769101200,
#    'temp': 37.37,
#    'feels_like': 36.72,
#    'pressure': 1007,
#    'humidity': 24,
#    'dew_point': 13.49,
#    'uvi': 8.06,
#    'clouds': 69,
#    'visibility': 10000,
#    'wind_speed': 3.77,
#    'wind_deg': 112,
#    'wind_gust': 4.61,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769104800,
#    'temp': 37.31,
#    'feels_like': 36.41,
#    'pressure': 1006,
#    'humidity': 23,
#    'dew_point': 13.11,
#    'uvi': 4.38,
#    'clouds': 59,
#    'visibility': 10000,
#    'wind_speed': 3.97,
#    'wind_deg': 112,
#    'wind_gust': 4.54,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769108400,
#    'temp': 36.88,
#    'feels_like': 35.83,
#    'pressure': 1005,
#    'humidity': 23,
#    'dew_point': 12.6,
#    'uvi': 1.63,
#    'clouds': 18,
#    'visibility': 10000,
#    'wind_speed': 3.54,
#    'wind_deg': 115,
#    'wind_gust': 3.95,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'algumas nuvens',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1769112000,
#    'temp': 35.38,
#    'feels_like': 34.8,
#    'pressure': 1005,
#    'humidity': 28,
#    'dew_point': 14.45,
#    'uvi': 0.3,
#    'clouds': 31,
#    'visibility': 10000,
#    'wind_speed': 3.86,
#    'wind_deg': 82,
#    'wind_gust': 3.97,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769115600,
#    'temp': 30.42,
#    'feels_like': 31.35,
#    'pressure': 1007,
#    'humidity': 48,
#    'dew_point': 18.32,
#    'uvi': 0,
#    'clouds': 50,
#    'visibility': 10000,
#    'wind_speed': 3.99,
#    'wind_deg': 48,
#    'wind_gust': 7.31,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769119200,
#    'temp': 27.66,
#    'feels_like': 28.77,
#    'pressure': 1008,
#    'humidity': 58,
#    'dew_point': 18.65,
#    'uvi': 0,
#    'clouds': 46,
#    'visibility': 10000,
#    'wind_speed': 2.68,
#    'wind_deg': 34,
#    'wind_gust': 5.62,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769122800,
#    'temp': 26.11,
#    'feels_like': 26.11,
#    'pressure': 1010,
#    'humidity': 64,
#    'dew_point': 18.74,
#    'uvi': 0,
#    'clouds': 48,
#    'visibility': 10000,
#    'wind_speed': 1.18,
#    'wind_deg': 18,
#    'wind_gust': 2.76,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769126400,
#    'temp': 25.15,
#    'feels_like': 25.52,
#    'pressure': 1011,
#    'humidity': 69,
#    'dew_point': 19.09,
#    'uvi': 0,
#    'clouds': 51,
#    'visibility': 10000,
#    'wind_speed': 1.87,
#    'wind_deg': 341,
#    'wind_gust': 2.42,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769130000,
#    'temp': 24.11,
#    'feels_like': 24.59,
#    'pressure': 1011,
#    'humidity': 77,
#    'dew_point': 19.68,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.43,
#    'wind_deg': 21,
#    'wind_gust': 2.62,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769133600,
#    'temp': 23.25,
#    'feels_like': 23.8,
#    'pressure': 1011,
#    'humidity': 83,
#    'dew_point': 20.1,
#    'uvi': 0,
#    'clouds': 73,
#    'visibility': 10000,
#    'wind_speed': 0.82,
#    'wind_deg': 58,
#    'wind_gust': 1.36,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769137200,
#    'temp': 22.87,
#    'feels_like': 23.48,
#    'pressure': 1011,
#    'humidity': 87,
#    'dew_point': 20.4,
#    'uvi': 0,
#    'clouds': 53,
#    'visibility': 10000,
#    'wind_speed': 0.19,
#    'wind_deg': 302,
#    'wind_gust': 0,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769140800,
#    'temp': 22.41,
#    'feels_like': 23.06,
#    'pressure': 1010,
#    'humidity': 90,
#    'dew_point': 20.51,
#    'uvi': 0,
#    'clouds': 39,
#    'visibility': 10000,
#    'wind_speed': 0.19,
#    'wind_deg': 69,
#    'wind_gust': 0,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769144400,
#    'temp': 22.13,
#    'feels_like': 22.8,
#    'pressure': 1009,
#    'humidity': 92,
#    'dew_point': 20.65,
#    'uvi': 0,
#    'clouds': 38,
#    'visibility': 10000,
#    'wind_speed': 1.25,
#    'wind_deg': 174,
#    'wind_gust': 0.3,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769148000,
#    'temp': 21.99,
#    'feels_like': 22.65,
#    'pressure': 1009,
#    'humidity': 92,
#    'dew_point': 20.52,
#    'uvi': 0,
#    'clouds': 39,
#    'visibility': 10000,
#    'wind_speed': 1.4,
#    'wind_deg': 169,
#    'wind_gust': 1.47,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769151600,
#    'temp': 21.86,
#    'feels_like': 22.5,
#    'pressure': 1010,
#    'humidity': 92,
#    'dew_point': 20.5,
#    'uvi': 0,
#    'clouds': 95,
#    'visibility': 10000,
#    'wind_speed': 1.46,
#    'wind_deg': 178,
#    'wind_gust': 1.38,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769155200,
#    'temp': 21.48,
#    'feels_like': 22.14,
#    'pressure': 1011,
#    'humidity': 94,
#    'dew_point': 20.36,
#    'uvi': 0,
#    'clouds': 53,
#    'visibility': 10000,
#    'wind_speed': 1.33,
#    'wind_deg': 194,
#    'wind_gust': 1.01,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769158800,
#    'temp': 22.05,
#    'feels_like': 22.69,
#    'pressure': 1011,
#    'humidity': 91,
#    'dew_point': 20.42,
#    'uvi': 0.16,
#    'clouds': 34,
#    'visibility': 10000,
#    'wind_speed': 1.14,
#    'wind_deg': 190,
#    'wind_gust': 1.34,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769162400,
#    'temp': 24.6,
#    'feels_like': 25.15,
#    'pressure': 1012,
#    'humidity': 78,
#    'dew_point': 20.27,
#    'uvi': 0.69,
#    'clouds': 39,
#    'visibility': 10000,
#    'wind_speed': 0.86,
#    'wind_deg': 156,
#    'wind_gust': 2.15,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769166000,
#    'temp': 26.85,
#    'feels_like': 28.31,
#    'pressure': 1012,
#    'humidity': 66,
#    'dew_point': 19.79,
#    'uvi': 1.54,
#    'clouds': 45,
#    'visibility': 10000,
#    'wind_speed': 1.81,
#    'wind_deg': 129,
#    'wind_gust': 4.38,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769169600,
#    'temp': 28.93,
#    'feels_like': 30.48,
#    'pressure': 1012,
#    'humidity': 57,
#    'dew_point': 18.97,
#    'uvi': 3.77,
#    'clouds': 54,
#    'visibility': 10000,
#    'wind_speed': 3.17,
#    'wind_deg': 140,
#    'wind_gust': 5.07,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769173200,
#    'temp': 31.24,
#    'feels_like': 32.62,
#    'pressure': 1012,
#    'humidity': 48,
#    'dew_point': 18.73,
#    'uvi': 10.62,
#    'clouds': 56,
#    'visibility': 10000,
#    'wind_speed': 3.71,
#    'wind_deg': 136,
#    'wind_gust': 4.73,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769176800,
#    'temp': 33.38,
#    'feels_like': 34.39,
#    'pressure': 1011,
#    'humidity': 40,
#    'dew_point': 18.01,
#    'uvi': 13.09,
#    'clouds': 45,
#    'visibility': 10000,
#    'wind_speed': 3.88,
#    'wind_deg': 127,
#    'wind_gust': 4.95,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769180400,
#    'temp': 35.07,
#    'feels_like': 35.69,
#    'pressure': 1010,
#    'humidity': 34,
#    'dew_point': 16.91,
#    'uvi': 13.5,
#    'clouds': 37,
#    'visibility': 10000,
#    'wind_speed': 4.28,
#    'wind_deg': 116,
#    'wind_gust': 4.81,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769184000,
#    'temp': 35.92,
#    'feels_like': 36.04,
#    'pressure': 1009,
#    'humidity': 30,
#    'dew_point': 15.92,
#    'uvi': 11.27,
#    'clouds': 29,
#    'visibility': 10000,
#    'wind_speed': 4.52,
#    'wind_deg': 113,
#    'wind_gust': 4.6,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769187600,
#    'temp': 36.68,
#    'feels_like': 36.45,
#    'pressure': 1008,
#    'humidity': 27,
#    'dew_point': 14.65,
#    'uvi': 7.91,
#    'clouds': 25,
#    'visibility': 10000,
#    'wind_speed': 3.82,
#    'wind_deg': 116,
#    'wind_gust': 4.33,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769191200,
#    'temp': 36.96,
#    'feels_like': 36.15,
#    'pressure': 1007,
#    'humidity': 24,
#    'dew_point': 13.48,
#    'uvi': 4.21,
#    'clouds': 22,
#    'visibility': 10000,
#    'wind_speed': 3.82,
#    'wind_deg': 124,
#    'wind_gust': 4.31,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'algumas nuvens',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1769194800,
#    'temp': 36.81,
#    'feels_like': 35.73,
#    'pressure': 1006,
#    'humidity': 23,
#    'dew_point': 12.67,
#    'uvi': 1.19,
#    'clouds': 58,
#    'visibility': 10000,
#    'wind_speed': 4.22,
#    'wind_deg': 122,
#    'wind_gust': 3.95,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769198400,
#    'temp': 35.56,
#    'feels_like': 34.65,
#    'pressure': 1007,
#    'humidity': 26,
#    'dew_point': 13.28,
#    'uvi': 0.21,
#    'clouds': 46,
#    'visibility': 10000,
#    'wind_speed': 3.54,
#    'wind_deg': 100,
#    'wind_gust': 3.99,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769202000,
#    'temp': 30.72,
#    'feels_like': 31.14,
#    'pressure': 1008,
#    'humidity': 44,
#    'dew_point': 17.25,
#    'uvi': 0,
#    'clouds': 46,
#    'visibility': 10000,
#    'wind_speed': 4.35,
#    'wind_deg': 57,
#    'wind_gust': 7.45,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0}],
#  'daily': [{'dt': 1769004000,
#    'sunrise': 1768984707,
#    'sunset': 1769029091,
#    'moonrise': 1768992540,
#    'moonset': 1769037360,
#    'moon_phase': 0.09,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 31.34,
#     'min': 22.19,
#     'max': 31.8,
#     'night': 25.03,
#     'eve': 28.82,
#     'morn': 22.19},
#    'feels_like': {'day': 32.39, 'night': 25.6, 'eve': 29.43, 'morn': 22.92},
#    'pressure': 1011,
#    'humidity': 46,
#    'dew_point': 17.88,
#    'wind_speed': 4.92,
#    'wind_deg': 102,
#    'wind_gust': 7.2,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'chuva leve',
#      'icon': '10d'}],
#    'clouds': 71,
#    'pop': 0.48,
#    'rain': 0.33,
#    'uvi': 12.67},
#   {'dt': 1769090400,
#    'sunrise': 1769071129,
#    'sunset': 1769115503,
#    'moonrise': 1769081700,
#    'moonset': 1769126280,
#    'moon_phase': 0.13,
#    'summary': 'Expect a day of partly cloudy with clear spells',
#    'temp': {'day': 34.06,
#     'min': 22.21,
#     'max': 37.37,
#     'night': 23.25,
#     'eve': 35.38,
#     'morn': 22.21},
#    'feels_like': {'day': 34.13, 'night': 23.8, 'eve': 34.8, 'morn': 22.91},
#    'pressure': 1010,
#    'humidity': 34,
#    'dew_point': 15.95,
#    'wind_speed': 4.27,
#    'wind_deg': 110,
#    'wind_gust': 7.31,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'clouds': 69,
#    'pop': 0,
#    'uvi': 13.22},
#   {'dt': 1769176800,
#    'sunrise': 1769157550,
#    'sunset': 1769201914,
#    'moonrise': 1769170920,
#    'moonset': 1769215320,
#    'moon_phase': 0.16,
#    'summary': 'There will be partly cloudy today',
#    'temp': {'day': 33.38,
#     'min': 21.48,
#     'max': 36.96,
#     'night': 22.9,
#     'eve': 35.56,
#     'morn': 21.48},
#    'feels_like': {'day': 34.39, 'night': 23.62, 'eve': 34.65, 'morn': 22.14},
#    'pressure': 1011,
#    'humidity': 40,
#    'dew_point': 18.01,
#    'wind_speed': 4.52,
#    'wind_deg': 113,
#    'wind_gust': 7.45,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'clouds': 45,
#    'pop': 0,
#    'uvi': 13.5},
#   {'dt': 1769263200,
#    'sunrise': 1769243971,
#    'sunset': 1769288324,
#    'moonrise': 1769260140,
#    'moonset': 1769304360,
#    'moon_phase': 0.19,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 31.58,
#     'min': 22.51,
#     'max': 33.11,
#     'night': 25.19,
#     'eve': 30.15,
#     'morn': 22.81},
#    'feels_like': {'day': 32.97, 'night': 25.54, 'eve': 31.78, 'morn': 23.42},
#    'pressure': 1012,
#    'humidity': 47,
#    'dew_point': 19.07,
#    'wind_speed': 3.17,
#    'wind_deg': 100,
#    'wind_gust': 5.15,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'chuva leve',
#      'icon': '10d'}],
#    'clouds': 90,
#    'pop': 0.9,
#    'rain': 0.79,
#    'uvi': 7.44},
#   {'dt': 1769349600,
#    'sunrise': 1769330391,
#    'sunset': 1769374734,
#    'moonrise': 1769349540,
#    'moonset': 1769393640,
#    'moon_phase': 0.23,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 33.44,
#     'min': 21.51,
#     'max': 33.44,
#     'night': 24.7,
#     'eve': 29.31,
#     'morn': 23.3},
#    'feels_like': {'day': 34.04, 'night': 25.13, 'eve': 30.34, 'morn': 23.77},
#    'pressure': 1011,
#    'humidity': 38,
#    'dew_point': 17.32,
#    'wind_speed': 4.51,
#    'wind_deg': 93,
#    'wind_gust': 7.01,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'chuva leve',
#      'icon': '10d'}],
#    'clouds': 99,
#    'pop': 0.21,
#    'rain': 0.3,
#    'uvi': 11.66},
#   {'dt': 1769436000,
#    'sunrise': 1769416810,
#    'sunset': 1769461142,
#    'moonrise': 1769439180,
#    'moonset': 0,
#    'moon_phase': 0.25,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 33.12,
#     'min': 22.68,
#     'max': 33.19,
#     'night': 23.92,
#     'eve': 28.59,
#     'morn': 23.15},
#    'feels_like': {'day': 34.43, 'night': 24.51, 'eve': 29.84, 'morn': 23.82},
#    'pressure': 1012,
#    'humidity': 42,
#    'dew_point': 18.48,
#    'wind_speed': 4.54,
#    'wind_deg': 121,
#    'wind_gust': 5.58,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'chuva leve',
#      'icon': '10d'}],
#    'clouds': 80,
#    'pop': 0.99,
#    'rain': 3.21,
#    'uvi': 7.25},
#   {'dt': 1769522400,
#    'sunrise': 1769503229,
#    'sunset': 1769547550,
#    'moonrise': 1769529060,
#    'moonset': 1769483160,
#    'moon_phase': 0.3,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 31.78,
#     'min': 23.23,
#     'max': 31.78,
#     'night': 23.31,
#     'eve': 25.44,
#     'morn': 23.31},
#    'feels_like': {'day': 33.52, 'night': 24.05, 'eve': 26.05, 'morn': 24.07},
#    'pressure': 1012,
#    'humidity': 48,
#    'dew_point': 19.27,
#    'wind_speed': 3.13,
#    'wind_deg': 127,
#    'wind_gust': 5.48,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'chuva moderada',
#      'icon': '10d'}],
#    'clouds': 89,
#    'pop': 1,
#    'rain': 12.48,
#    'uvi': 8},
#   {'dt': 1769608800,
#    'sunrise': 1769589647,
#    'sunset': 1769633957,
#    'moonrise': 1769619240,
#    'moonset': 1769572980,
#    'moon_phase': 0.34,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 28.76,
#     'min': 22.17,
#     'max': 30.95,
#     'night': 24.35,
#     'eve': 27.39,
#     'morn': 22.17},
#    'feels_like': {'day': 29.96, 'night': 24.88, 'eve': 28.5, 'morn': 22.92},
#    'pressure': 1013,
#    'humidity': 55,
#    'dew_point': 18.62,
#    'wind_speed': 4.73,
#    'wind_deg': 115,
#    'wind_gust': 6.86,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'chuva leve',
#      'icon': '10d'}],
#    'clouds': 85,
#    'pop': 0.23,
#    'rain': 0.27,
#    'uvi': 8}]}

# %%
result["current"]["weather"][0]["description"]
# Out:
# 'nublado'

# %% [markdown]
# ## Functions que serão utilizadas pelo LLM

# %%
def get_weather(lat:float, lon:float, api_key=open_weather_key) -> str:

    """ 
    Essa função nos informa o clima  do ponto dado por 
    latitude=lat e longitude=lon no momento exato em que é chamada
    """

    if not api_key:
        return {"error": "OpenWeather api key not set"}
    
    url = (
    f"https://api.openweathermap.org/data/3.0/onecall"
    f"?lat={lat}&lon={lon}"
    f"&appid={open_weather_key}"
    f"&units=metric&lang=pt_br"
    )

    response = requests.get(url)
    result = json.loads(response.content)

    return f"O clima em lat={lat} e lon={lon}, região da {result["timezone"]}, é {result["current"]["weather"][0]["description"]}"

print(get_weather(8.36666, 115.15))
# Out:
# O clima em lat=8.36666 e lon=115.15, região da Asia/Manila, é nublado

# %%
def send_email_stup(to:str, subject:str, body:str) -> dict:
    """Stub simples: em prod troque por SendGrid/Mailgun/SMTP real."""
    return {"sent": True, "to": to, "subject": subject}

# %% [markdown]
# ## Schema para o modelo (Function Calling)

# %%
functions = [
    {   
        "type": "function",
        "name": "get_weather",
        "description": "Retorna temperatura e descrição do tempo para uma cidade.",
        "parameters": {
            "type": "object",
            "properties": {
                "lat": {
                    "type": "number",
                    "minimum": -90,
                    "maximum": 90,
                    "description": "Latitude (ex: -3.171722)"},
                "lon": {
                    "type": "number",
                    "minimum":-180,
                    "maximum":180,
                    "description": "Longitude (ex: -38.5434)"},
                "api_key": {"type": "string"}
            },
            "required": ["lat", "lon"]
        }
    },
    {   
        "type": "function",
        "name": "send_email",
        "description": "Envia um email simples.",
        "parameters": {
            "type": "object",
            "properties": {
                "to": {"type": "string"},
                "subject": {"type": "string"},
                "body": {"type": "string"}
            },
            "required": ["to", "subject", "body"]
        }
    }
]

# %% [markdown]
# ## Workflow

# %%
input = (
    "Verifique o tempo em Fortaleza hoje. "
    "Se estiver chuvoso, envie um email para iran@example.com pedindo que leve guarda-chuva."
)

client_openai = OpenAI(api_key=openai_api_key)

response = client_openai.responses.parse(
    model="gpt-4.1-mini",
    input=input,
    temperature=0.0, 
    tools=functions
)

# %%
response
# Out:
# ParsedResponse[NoneType](id='resp_0eb89b6b74f4d1a60069714e31d5d08195ac8a3abbb66b1756', created_at=1769033265.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-mini-2025-04-14', object='response', output=[ParsedResponseFunctionToolCall(arguments='{"lat":-3.71722,"lon":-38.5434,"api_key":"your_openweather_api_key"}', call_id='call_WiRjMP3AJHtpogIzmcNAHOOn', name='get_weather', type='function_call', id='fc_0eb89b6b74f4d1a60069714e32a4148195a0701994f0c82663', status='completed', parsed_arguments=None)], parallel_tool_calls=True, temperature=0.0, tool_choice='auto', tools=[FunctionTool(name='get_weather', parameters={'type': 'object', 'properties': {'lat': {'type': 'number', 'minimum': -90, 'maximum': 90, 'description': 'Latitude (ex: -3.171722)'}, 'lon': {'type': 'number', 'minimum': -180, 'maximum': 180, 'description': 'Longitude (ex: -38.5434)'}, 'api_key': {'type': 'string'}}, 'required': ['lat', 'lon', 'api_key'], 'additionalProperties': False}, strict=True, type='function', description='Retorna temperatura e descrição do tempo para uma cidade.'), FunctionTool(name='send_email', parameters={'type': 'object', 'properties': {'to': {'type': 'string'}, 'subject': {'type': 'string'}, 'body': {'type': 'string'}}, 'required': ['to', 'subject', 'body'], 'additionalProperties': False}, strict=True, type='function', description='Envia um email simples.')], top_p=1.0, background=False, completed_at=1769033266.0, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort=None, generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=160, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=36, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=196), user=None, billing={'payer': 'developer'}, frequency_penalty=0.0, presence_penalty=0.0, store=True)
