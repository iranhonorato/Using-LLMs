# %% [markdown]
# # Function Calling
#
# **Function calling** é, de fato, uma estratégia de fornecer ao LLM um “esqueleto” estruturado (normalmente em JSON Schema) descrevendo:
#
# - Nome da função
# - O que ela faz
# - Quais argumentos aceita
# - Tipo/formato desses argumentos
# - Quais campos são obrigatórios
#
# Isso guia o modelo a:
# - Entender quando usar a função
# - Como montar corretamente os argumentos
# - Devolver uma saída estruturada e válida, reduzindo erros
#
# Ou seja: não é para o LLM executar a função, e sim para pedir corretamente que ela seja executada pelo seu código.

# %%
import os, json
from dotenv import dotenv_values
import requests
from openai import OpenAI

config = dotenv_values("../.env")
openai_api_key = config["OPENAI_API_KEY"]
open_weather_key = config["OPEN_WEATHER"]

# %% [markdown]
# ## Testando API Open Weather

# %%
lat = -4.35795
lon = -39.3024
url = (
    f"https://api.openweathermap.org/data/3.0/onecall"
    f"?lat={lat}&lon={lon}"
    f"&appid={open_weather_key}"
    f"&units=metric&lang=pt_br"
) 


resp = requests.get(url)  
resp.status_code
# Out:
# 200

# %%
result = json.loads(resp.content)
result
# Out:
# {'lat': -4.358,
#  'lon': -39.3024,
#  'timezone': 'America/Fortaleza',
#  'timezone_offset': -10800,
#  'current': {'dt': 1769184205,
#   'sunrise': 1769157550,
#   'sunset': 1769201914,
#   'temp': 33.35,
#   'feels_like': 33.3,
#   'pressure': 1008,
#   'humidity': 35,
#   'dew_point': 15.81,
#   'uvi': 11.41,
#   'clouds': 63,
#   'visibility': 10000,
#   'wind_speed': 4,
#   'wind_deg': 115,
#   'wind_gust': 4.7,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'nublado',
#     'icon': '04d'}]},
#  'minutely': [{'dt': 1769184240, 'precipitation': 0},
#   {'dt': 1769184300, 'precipitation': 0},
#   {'dt': 1769184360, 'precipitation': 0},
#   {'dt': 1769184420, 'precipitation': 0},
#   {'dt': 1769184480, 'precipitation': 0},
#   {'dt': 1769184540, 'precipitation': 0},
#   {'dt': 1769184600, 'precipitation': 0},
#   {'dt': 1769184660, 'precipitation': 0},
#   {'dt': 1769184720, 'precipitation': 0},
#   {'dt': 1769184780, 'precipitation': 0},
#   {'dt': 1769184840, 'precipitation': 0},
#   {'dt': 1769184900, 'precipitation': 0},
#   {'dt': 1769184960, 'precipitation': 0},
#   {'dt': 1769185020, 'precipitation': 0},
#   {'dt': 1769185080, 'precipitation': 0},
#   {'dt': 1769185140, 'precipitation': 0},
#   {'dt': 1769185200, 'precipitation': 0},
#   {'dt': 1769185260, 'precipitation': 0},
#   {'dt': 1769185320, 'precipitation': 0},
#   {'dt': 1769185380, 'precipitation': 0},
#   {'dt': 1769185440, 'precipitation': 0},
#   {'dt': 1769185500, 'precipitation': 0},
#   {'dt': 1769185560, 'precipitation': 0},
#   {'dt': 1769185620, 'precipitation': 0},
#   {'dt': 1769185680, 'precipitation': 0},
#   {'dt': 1769185740, 'precipitation': 0},
#   {'dt': 1769185800, 'precipitation': 0},
#   {'dt': 1769185860, 'precipitation': 0},
#   {'dt': 1769185920, 'precipitation': 0},
#   {'dt': 1769185980, 'precipitation': 0},
#   {'dt': 1769186040, 'precipitation': 0},
#   {'dt': 1769186100, 'precipitation': 0},
#   {'dt': 1769186160, 'precipitation': 0},
#   {'dt': 1769186220, 'precipitation': 0},
#   {'dt': 1769186280, 'precipitation': 0},
#   {'dt': 1769186340, 'precipitation': 0},
#   {'dt': 1769186400, 'precipitation': 0},
#   {'dt': 1769186460, 'precipitation': 0},
#   {'dt': 1769186520, 'precipitation': 0},
#   {'dt': 1769186580, 'precipitation': 0},
#   {'dt': 1769186640, 'precipitation': 0},
#   {'dt': 1769186700, 'precipitation': 0},
#   {'dt': 1769186760, 'precipitation': 0},
#   {'dt': 1769186820, 'precipitation': 0},
#   {'dt': 1769186880, 'precipitation': 0},
#   {'dt': 1769186940, 'precipitation': 0},
#   {'dt': 1769187000, 'precipitation': 0},
#   {'dt': 1769187060, 'precipitation': 0},
#   {'dt': 1769187120, 'precipitation': 0},
#   {'dt': 1769187180, 'precipitation': 0},
#   {'dt': 1769187240, 'precipitation': 0},
#   {'dt': 1769187300, 'precipitation': 0},
#   {'dt': 1769187360, 'precipitation': 0},
#   {'dt': 1769187420, 'precipitation': 0},
#   {'dt': 1769187480, 'precipitation': 0},
#   {'dt': 1769187540, 'precipitation': 0},
#   {'dt': 1769187600, 'precipitation': 0},
#   {'dt': 1769187660, 'precipitation': 0},
#   {'dt': 1769187720, 'precipitation': 0},
#   {'dt': 1769187780, 'precipitation': 0}],
#  'hourly': [{'dt': 1769184000,
#    'temp': 33.35,
#    'feels_like': 33.3,
#    'pressure': 1008,
#    'humidity': 35,
#    'dew_point': 15.81,
#    'uvi': 11.41,
#    'clouds': 63,
#    'visibility': 10000,
#    'wind_speed': 4,
#    'wind_deg': 115,
#    'wind_gust': 4.7,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769187600,
#    'temp': 33.44,
#    'feels_like': 33.05,
#    'pressure': 1008,
#    'humidity': 33,
#    'dew_point': 14.98,
#    'uvi': 8.11,
#    'clouds': 61,
#    'visibility': 10000,
#    'wind_speed': 3.89,
#    'wind_deg': 117,
#    'wind_gust': 4.39,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769191200,
#    'temp': 33.74,
#    'feels_like': 33.11,
#    'pressure': 1007,
#    'humidity': 31,
#    'dew_point': 14.27,
#    'uvi': 4.44,
#    'clouds': 61,
#    'visibility': 10000,
#    'wind_speed': 3.63,
#    'wind_deg': 123,
#    'wind_gust': 4.15,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769194800,
#    'temp': 33.96,
#    'feels_like': 33.06,
#    'pressure': 1007,
#    'humidity': 29,
#    'dew_point': 13.43,
#    'uvi': 1.66,
#    'clouds': 59,
#    'visibility': 10000,
#    'wind_speed': 3.76,
#    'wind_deg': 98,
#    'wind_gust': 4.02,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769198400,
#    'temp': 32.77,
#    'feels_like': 33.03,
#    'pressure': 1007,
#    'humidity': 38,
#    'dew_point': 16.59,
#    'uvi': 0.31,
#    'clouds': 73,
#    'visibility': 10000,
#    'wind_speed': 5.07,
#    'wind_deg': 61,
#    'wind_gust': 5.86,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769202000,
#    'temp': 30.46,
#    'feels_like': 31.75,
#    'pressure': 1008,
#    'humidity': 50,
#    'dew_point': 18.34,
#    'uvi': 0,
#    'clouds': 64,
#    'visibility': 10000,
#    'wind_speed': 4.34,
#    'wind_deg': 44,
#    'wind_gust': 7.62,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769205600,
#    'temp': 28.3,
#    'feels_like': 29.9,
#    'pressure': 1010,
#    'humidity': 60,
#    'dew_point': 18.83,
#    'uvi': 0,
#    'clouds': 49,
#    'visibility': 10000,
#    'wind_speed': 2.74,
#    'wind_deg': 14,
#    'wind_gust': 4.49,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769209200,
#    'temp': 26.89,
#    'feels_like': 28.37,
#    'pressure': 1011,
#    'humidity': 66,
#    'dew_point': 19.11,
#    'uvi': 0,
#    'clouds': 40,
#    'visibility': 10000,
#    'wind_speed': 1.9,
#    'wind_deg': 359,
#    'wind_gust': 3.42,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769212800,
#    'temp': 25.92,
#    'feels_like': 26.45,
#    'pressure': 1012,
#    'humidity': 72,
#    'dew_point': 19.43,
#    'uvi': 0,
#    'clouds': 38,
#    'visibility': 10000,
#    'wind_speed': 2,
#    'wind_deg': 1,
#    'wind_gust': 3.81,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769216400,
#    'temp': 24.97,
#    'feels_like': 25.56,
#    'pressure': 1012,
#    'humidity': 78,
#    'dew_point': 19.75,
#    'uvi': 0,
#    'clouds': 75,
#    'visibility': 10000,
#    'wind_speed': 1.91,
#    'wind_deg': 2,
#    'wind_gust': 3.73,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769220000,
#    'temp': 24.38,
#    'feels_like': 25.07,
#    'pressure': 1012,
#    'humidity': 84,
#    'dew_point': 19.93,
#    'uvi': 0,
#    'clouds': 93,
#    'visibility': 10000,
#    'wind_speed': 1.18,
#    'wind_deg': 4,
#    'wind_gust': 1.65,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769223600,
#    'temp': 23.93,
#    'feels_like': 24.68,
#    'pressure': 1012,
#    'humidity': 88,
#    'dew_point': 20.09,
#    'uvi': 0,
#    'clouds': 64,
#    'visibility': 10000,
#    'wind_speed': 0.89,
#    'wind_deg': 333,
#    'wind_gust': 0,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769227200,
#    'temp': 23.57,
#    'feels_like': 24.36,
#    'pressure': 1011,
#    'humidity': 91,
#    'dew_point': 20.25,
#    'uvi': 0,
#    'clouds': 49,
#    'visibility': 10000,
#    'wind_speed': 0.67,
#    'wind_deg': 284,
#    'wind_gust': 0,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769230800,
#    'temp': 23.32,
#    'feels_like': 24.14,
#    'pressure': 1011,
#    'humidity': 93,
#    'dew_point': 20.37,
#    'uvi': 0,
#    'clouds': 43,
#    'visibility': 10000,
#    'wind_speed': 0.53,
#    'wind_deg': 253,
#    'wind_gust': 0,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769234400,
#    'temp': 23.23,
#    'feels_like': 24.06,
#    'pressure': 1011,
#    'humidity': 94,
#    'dew_point': 20.42,
#    'uvi': 0,
#    'clouds': 42,
#    'visibility': 10000,
#    'wind_speed': 0.9,
#    'wind_deg': 183,
#    'wind_gust': 0,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1769238000,
#    'temp': 22.46,
#    'feels_like': 23.09,
#    'pressure': 1012,
#    'humidity': 89,
#    'dew_point': 20.43,
#    'uvi': 0,
#    'clouds': 65,
#    'visibility': 10000,
#    'wind_speed': 1.03,
#    'wind_deg': 196,
#    'wind_gust': 0.85,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769241600,
#    'temp': 23.87,
#    'feels_like': 24.4,
#    'pressure': 1012,
#    'humidity': 80,
#    'dew_point': 20.23,
#    'uvi': 0,
#    'clouds': 83,
#    'visibility': 10000,
#    'wind_speed': 0.51,
#    'wind_deg': 138,
#    'wind_gust': 3.41,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769245200,
#    'temp': 23.62,
#    'feels_like': 24.15,
#    'pressure': 1013,
#    'humidity': 81,
#    'dew_point': 20.12,
#    'uvi': 0.17,
#    'clouds': 82,
#    'visibility': 10000,
#    'wind_speed': 0.31,
#    'wind_deg': 163,
#    'wind_gust': 0.38,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769248800,
#    'temp': 25.55,
#    'feels_like': 26.01,
#    'pressure': 1013,
#    'humidity': 71,
#    'dew_point': 19.81,
#    'uvi': 1.14,
#    'clouds': 74,
#    'visibility': 10000,
#    'wind_speed': 1.36,
#    'wind_deg': 91,
#    'wind_gust': 3.55,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769252400,
#    'temp': 27.84,
#    'feels_like': 29.11,
#    'pressure': 1013,
#    'humidity': 59,
#    'dew_point': 19.07,
#    'uvi': 3.4,
#    'clouds': 67,
#    'visibility': 10000,
#    'wind_speed': 2.39,
#    'wind_deg': 87,
#    'wind_gust': 4.65,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769256000,
#    'temp': 30.31,
#    'feels_like': 31.35,
#    'pressure': 1013,
#    'humidity': 49,
#    'dew_point': 18.49,
#    'uvi': 6.94,
#    'clouds': 69,
#    'visibility': 10000,
#    'wind_speed': 3.07,
#    'wind_deg': 101,
#    'wind_gust': 4.86,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769259600,
#    'temp': 32.25,
#    'feels_like': 33.03,
#    'pressure': 1012,
#    'humidity': 42,
#    'dew_point': 17.58,
#    'uvi': 8.76,
#    'clouds': 46,
#    'visibility': 10000,
#    'wind_speed': 3.3,
#    'wind_deg': 108,
#    'wind_gust': 4.73,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769263200,
#    'temp': 34.03,
#    'feels_like': 34.3,
#    'pressure': 1012,
#    'humidity': 35,
#    'dew_point': 16.46,
#    'uvi': 5.53,
#    'clouds': 57,
#    'visibility': 10000,
#    'wind_speed': 3.31,
#    'wind_deg': 112,
#    'wind_gust': 4.63,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769266800,
#    'temp': 36.08,
#    'feels_like': 36.04,
#    'pressure': 1010,
#    'humidity': 29,
#    'dew_point': 15.13,
#    'uvi': 4.03,
#    'clouds': 57,
#    'visibility': 10000,
#    'wind_speed': 3.54,
#    'wind_deg': 114,
#    'wind_gust': 4.55,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769270400,
#    'temp': 37.19,
#    'feels_like': 36.71,
#    'pressure': 1009,
#    'humidity': 25,
#    'dew_point': 13.99,
#    'uvi': 3.89,
#    'clouds': 49,
#    'visibility': 10000,
#    'wind_speed': 3.84,
#    'wind_deg': 116,
#    'wind_gust': 4.38,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769274000,
#    'temp': 37.64,
#    'feels_like': 36.86,
#    'pressure': 1008,
#    'humidity': 23,
#    'dew_point': 13.22,
#    'uvi': 1.74,
#    'clouds': 39,
#    'visibility': 10000,
#    'wind_speed': 3.79,
#    'wind_deg': 117,
#    'wind_gust': 3.97,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769277600,
#    'temp': 37.74,
#    'feels_like': 36.77,
#    'pressure': 1007,
#    'humidity': 22,
#    'dew_point': 12.54,
#    'uvi': 1.69,
#    'clouds': 35,
#    'visibility': 10000,
#    'wind_speed': 3.67,
#    'wind_deg': 118,
#    'wind_gust': 3.85,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'nuvens dispersas',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1769281200,
#    'temp': 37.07,
#    'feels_like': 35.87,
#    'pressure': 1007,
#    'humidity': 22,
#    'dew_point': 11.92,
#    'uvi': 1.53,
#    'clouds': 87,
#    'visibility': 10000,
#    'wind_speed': 3,
#    'wind_deg': 112,
#    'wind_gust': 3.65,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769284800,
#    'temp': 35.36,
#    'feels_like': 34.38,
#    'pressure': 1007,
#    'humidity': 26,
#    'dew_point': 13.25,
#    'uvi': 0.21,
#    'clouds': 75,
#    'visibility': 10000,
#    'wind_speed': 3.46,
#    'wind_deg': 72,
#    'wind_gust': 3.91,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769288400,
#    'temp': 30.68,
#    'feels_like': 30.78,
#    'pressure': 1009,
#    'humidity': 42,
#    'dew_point': 16.22,
#    'uvi': 0,
#    'clouds': 76,
#    'visibility': 10000,
#    'wind_speed': 4.79,
#    'wind_deg': 51,
#    'wind_gust': 8.27,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769292000,
#    'temp': 27.47,
#    'feels_like': 28.27,
#    'pressure': 1011,
#    'humidity': 55,
#    'dew_point': 17.65,
#    'uvi': 0,
#    'clouds': 72,
#    'visibility': 10000,
#    'wind_speed': 2.76,
#    'wind_deg': 23,
#    'wind_gust': 5.47,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769295600,
#    'temp': 26.01,
#    'feels_like': 26.01,
#    'pressure': 1012,
#    'humidity': 63,
#    'dew_point': 18.41,
#    'uvi': 0,
#    'clouds': 81,
#    'visibility': 10000,
#    'wind_speed': 1.85,
#    'wind_deg': 356,
#    'wind_gust': 3.33,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769299200,
#    'temp': 24.71,
#    'feels_like': 25.12,
#    'pressure': 1013,
#    'humidity': 72,
#    'dew_point': 19.29,
#    'uvi': 0,
#    'clouds': 84,
#    'visibility': 10000,
#    'wind_speed': 1.32,
#    'wind_deg': 354,
#    'wind_gust': 2.5,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769302800,
#    'temp': 23.61,
#    'feels_like': 24.14,
#    'pressure': 1013,
#    'humidity': 81,
#    'dew_point': 19.98,
#    'uvi': 0,
#    'clouds': 88,
#    'visibility': 10000,
#    'wind_speed': 1.5,
#    'wind_deg': 355,
#    'wind_gust': 2.31,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769306400,
#    'temp': 22.75,
#    'feels_like': 23.35,
#    'pressure': 1013,
#    'humidity': 87,
#    'dew_point': 20.41,
#    'uvi': 0,
#    'clouds': 94,
#    'visibility': 10000,
#    'wind_speed': 0.97,
#    'wind_deg': 17,
#    'wind_gust': 1.51,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769310000,
#    'temp': 22.29,
#    'feels_like': 22.95,
#    'pressure': 1012,
#    'humidity': 91,
#    'dew_point': 20.65,
#    'uvi': 0,
#    'clouds': 96,
#    'visibility': 10000,
#    'wind_speed': 0.41,
#    'wind_deg': 6,
#    'wind_gust': 0,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769313600,
#    'temp': 22.02,
#    'feels_like': 22.73,
#    'pressure': 1012,
#    'humidity': 94,
#    'dew_point': 20.89,
#    'uvi': 0,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 0.39,
#    'wind_deg': 299,
#    'wind_gust': 0,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769317200,
#    'temp': 21.78,
#    'feels_like': 22.55,
#    'pressure': 1012,
#    'humidity': 97,
#    'dew_point': 21.08,
#    'uvi': 0,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 0.72,
#    'wind_deg': 203,
#    'wind_gust': 0,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769320800,
#    'temp': 21.77,
#    'feels_like': 22.54,
#    'pressure': 1012,
#    'humidity': 97,
#    'dew_point': 21.11,
#    'uvi': 0,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 1.83,
#    'wind_deg': 194,
#    'wind_gust': 1.85,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769324400,
#    'temp': 22.39,
#    'feels_like': 23.11,
#    'pressure': 1012,
#    'humidity': 93,
#    'dew_point': 21.16,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.59,
#    'wind_deg': 189,
#    'wind_gust': 3.06,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769328000,
#    'temp': 23.15,
#    'feels_like': 23.82,
#    'pressure': 1013,
#    'humidity': 88,
#    'dew_point': 20.83,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.45,
#    'wind_deg': 164,
#    'wind_gust': 3.68,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1769331600,
#    'temp': 24.14,
#    'feels_like': 24.67,
#    'pressure': 1013,
#    'humidity': 79,
#    'dew_point': 20.28,
#    'uvi': 0.08,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.47,
#    'wind_deg': 149,
#    'wind_gust': 4.11,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769335200,
#    'temp': 25.83,
#    'feels_like': 26.17,
#    'pressure': 1014,
#    'humidity': 65,
#    'dew_point': 18.64,
#    'uvi': 0.89,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 2.76,
#    'wind_deg': 114,
#    'wind_gust': 4.88,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769338800,
#    'temp': 27.07,
#    'feels_like': 28.1,
#    'pressure': 1014,
#    'humidity': 59,
#    'dew_point': 18.3,
#    'uvi': 3.21,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 3.02,
#    'wind_deg': 114,
#    'wind_gust': 4.61,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769342400,
#    'temp': 27.86,
#    'feels_like': 28.84,
#    'pressure': 1014,
#    'humidity': 56,
#    'dew_point': 18.11,
#    'uvi': 7.04,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 3.11,
#    'wind_deg': 122,
#    'wind_gust': 4.48,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769346000,
#    'temp': 29.73,
#    'feels_like': 30.51,
#    'pressure': 1014,
#    'humidity': 49,
#    'dew_point': 17.56,
#    'uvi': 10.68,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 3.31,
#    'wind_deg': 132,
#    'wind_gust': 4.67,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769349600,
#    'temp': 32.33,
#    'feels_like': 32.57,
#    'pressure': 1013,
#    'humidity': 39,
#    'dew_point': 16.7,
#    'uvi': 13.02,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 2.95,
#    'wind_deg': 124,
#    'wind_gust': 4.66,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1769353200,
#    'temp': 34.7,
#    'feels_like': 34.88,
#    'pressure': 1012,
#    'humidity': 33,
#    'dew_point': 16.16,
#    'uvi': 13.01,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 2.88,
#    'wind_deg': 105,
#    'wind_gust': 4.63,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'pop': 0}],
#  'daily': [{'dt': 1769176800,
#    'sunrise': 1769157550,
#    'sunset': 1769201914,
#    'moonrise': 1769170920,
#    'moonset': 1769215320,
#    'moon_phase': 0.16,
#    'summary': 'There will be clear sky until morning, then partly cloudy',
#    'temp': {'day': 32.68,
#     'min': 23.52,
#     'max': 33.96,
#     'night': 24.38,
#     'eve': 32.77,
#     'morn': 23.52},
#    'feels_like': {'day': 33.09, 'night': 25.07, 'eve': 33.03, 'morn': 24.23},
#    'pressure': 1009,
#    'humidity': 39,
#    'dew_point': 16.92,
#    'wind_speed': 5.07,
#    'wind_deg': 61,
#    'wind_gust': 7.62,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'clouds': 71,
#    'pop': 0,
#    'uvi': 11.73},
#   {'dt': 1769263200,
#    'sunrise': 1769243971,
#    'sunset': 1769288324,
#    'moonrise': 1769260140,
#    'moonset': 1769304360,
#    'moon_phase': 0.19,
#    'summary': 'There will be partly cloudy today',
#    'temp': {'day': 34.03,
#     'min': 22.46,
#     'max': 37.74,
#     'night': 22.75,
#     'eve': 35.36,
#     'morn': 23.87},
#    'feels_like': {'day': 34.3, 'night': 23.35, 'eve': 34.38, 'morn': 24.4},
#    'pressure': 1012,
#    'humidity': 35,
#    'dew_point': 16.46,
#    'wind_speed': 4.79,
#    'wind_deg': 51,
#    'wind_gust': 8.27,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'clouds': 57,
#    'pop': 0,
#    'uvi': 8.76},
#   {'dt': 1769349600,
#    'sunrise': 1769330391,
#    'sunset': 1769374734,
#    'moonrise': 1769349540,
#    'moonset': 1769393640,
#    'moon_phase': 0.23,
#    'summary': 'There will be partly cloudy today',
#    'temp': {'day': 32.33,
#     'min': 21.77,
#     'max': 36.59,
#     'night': 23.33,
#     'eve': 35.43,
#     'morn': 23.15},
#    'feels_like': {'day': 32.57, 'night': 23.94, 'eve': 34.48, 'morn': 23.82},
#    'pressure': 1013,
#    'humidity': 39,
#    'dew_point': 16.7,
#    'wind_speed': 4.92,
#    'wind_deg': 47,
#    'wind_gust': 9.03,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'nublado',
#      'icon': '04d'}],
#    'clouds': 100,
#    'pop': 0,
#    'uvi': 13.02},
#   {'dt': 1769436000,
#    'sunrise': 1769416810,
#    'sunset': 1769461142,
#    'moonrise': 1769439180,
#    'moonset': 0,
#    'moon_phase': 0.25,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 33.12,
#     'min': 22.76,
#     'max': 35.86,
#     'night': 24.19,
#     'eve': 27.02,
#     'morn': 22.83},
#    'feels_like': {'day': 34.66, 'night': 24.86, 'eve': 28.64, 'morn': 23.57},
#    'pressure': 1013,
#    'humidity': 43,
#    'dew_point': 18.84,
#    'wind_speed': 4.05,
#    'wind_deg': 124,
#    'wind_gust': 7.94,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'chuva leve',
#      'icon': '10d'}],
#    'clouds': 99,
#    'pop': 1,
#    'rain': 3.63,
#    'uvi': 13.69},
#   {'dt': 1769522400,
#    'sunrise': 1769503229,
#    'sunset': 1769547550,
#    'moonrise': 1769529060,
#    'moonset': 1769483160,
#    'moon_phase': 0.3,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 25.43,
#     'min': 22.5,
#     'max': 27.15,
#     'night': 23.13,
#     'eve': 23.55,
#     'morn': 22.5},
#    'feels_like': {'day': 26.07, 'night': 23.9, 'eve': 24.31, 'morn': 23.26},
#    'pressure': 1014,
#    'humidity': 78,
#    'dew_point': 21.14,
#    'wind_speed': 2.55,
#    'wind_deg': 104,
#    'wind_gust': 4.65,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'chuva moderada',
#      'icon': '10d'}],
#    'clouds': 99,
#    'pop': 1,
#    'rain': 14.22,
#    'uvi': 4.2},
#   {'dt': 1769608800,
#    'sunrise': 1769589647,
#    'sunset': 1769633957,
#    'moonrise': 1769619240,
#    'moonset': 1769572980,
#    'moon_phase': 0.34,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 32.01,
#     'min': 22.13,
#     'max': 32.01,
#     'night': 23.7,
#     'eve': 26.37,
#     'morn': 22.25},
#    'feels_like': {'day': 33.69, 'night': 24.24, 'eve': 26.37, 'morn': 23.01},
#    'pressure': 1012,
#    'humidity': 47,
#    'dew_point': 19.25,
#    'wind_speed': 3.74,
#    'wind_deg': 104,
#    'wind_gust': 5.12,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'chuva leve',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 0.95,
#    'rain': 1.64,
#    'uvi': 5},
#   {'dt': 1769695200,
#    'sunrise': 1769676065,
#    'sunset': 1769720363,
#    'moonrise': 1769709540,
#    'moonset': 1769663100,
#    'moon_phase': 0.38,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 30.14,
#     'min': 22.21,
#     'max': 30.14,
#     'night': 23.55,
#     'eve': 25.87,
#     'morn': 22.35},
#    'feels_like': {'day': 32.9, 'night': 24.26, 'eve': 26.47, 'morn': 23.07},
#    'pressure': 1012,
#    'humidity': 59,
#    'dew_point': 21.15,
#    'wind_speed': 3.19,
#    'wind_deg': 103,
#    'wind_gust': 5.66,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'chuva leve',
#      'icon': '10d'}],
#    'clouds': 87,
#    'pop': 1,
#    'rain': 7.71,
#    'uvi': 5},
#   {'dt': 1769781600,
#    'sunrise': 1769762481,
#    'sunset': 1769806768,
#    'moonrise': 1769799720,
#    'moonset': 1769753400,
#    'moon_phase': 0.41,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 30.6,
#     'min': 22.35,
#     'max': 30.6,
#     'night': 23.47,
#     'eve': 26.05,
#     'morn': 22.35},
#    'feels_like': {'day': 32.15, 'night': 24.04, 'eve': 26.05, 'morn': 23.1},
#    'pressure': 1012,
#    'humidity': 51,
#    'dew_point': 19.12,
#    'wind_speed': 3.34,
#    'wind_deg': 83,
#    'wind_gust': 4.98,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'chuva leve',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 1,
#    'rain': 2.28,
#    'uvi': 5}]}

# %%
result["current"]["weather"][0]["description"]
# Out:
# 'nublado'

# %% [markdown]
# ## Functions que serão utilizadas pelo LLM

# %%
def get_weather(lat:float, lon:float, api_key=open_weather_key) -> str:

    """ 
    Essa função nos informa o clima  do ponto dado por 
    latitude=lat e longitude=lon no momento exato em que é chamada
    """
    print("chamando a função get_weather")
    
    if not api_key:
        return {"error": "OpenWeather api key not set"}
    
    url = (
    f"https://api.openweathermap.org/data/3.0/onecall"
    f"?lat={lat}&lon={lon}"
    f"&appid={open_weather_key}"
    f"&units=metric&lang=pt_br"
    )

    response = requests.get(url)
    result = json.loads(response.content)

    return f"O clima em lat={lat} e lon={lon}, região da {result["timezone"]}, é {result["current"]["weather"][0]["description"]}"

print(get_weather(8.36666, 115.15))
# Out:
# chamando a função get_weather
# O clima em lat=8.36666 e lon=115.15, região da Asia/Manila, é nublado

# %%
def get_horoscope(signo:str) -> str:
    """ Essa função retorna o horóscopo de hoje para um determinado signo astrológico """
    return f"{signo}: Próxima sexta você viajará para São Paulo"

print(get_horoscope("libra"))
# Out:
# libra: Próxima sexta você viajará para São Paulo

# %% [markdown]
# ## Schema para o modelo (Function Calling)

# %%
functions = [
    {   
        "type": "function",
        "name": "get_weather",
        "description": "Retorna temperatura e descrição do tempo para coordenadas (lat, lon).",
        "parameters": {
            "type": "object",
            "properties": {
                "lat": {"type": "number", "minimum": -90, "maximum": 90, "description": "Latitude"},
                "lon": {"type": "number", "minimum": -180, "maximum": 180, "description": "Longitude"},
            },
            "required": ["lat", "lon"]
        }
    },
    {   
        "type": "function",
        "name": "get_horoscope",
        "description": "Retorna o horóscopo de hoje para um signo astrológico (ex: Peixes).",
        "parameters": {
            "type": "object",
            "properties": {
                "signo": {"type": "string", "description": "Um signo astrológico como Touro ou Aquário"}
            },
            "required": ["signo"]
        }
    }
]

# %% [markdown]
# ## Workflow

# %% [markdown]
# ### 1ª chamada → decide tool

# %%
input_list = [{
    "role": "user",
    "content": "Qual o meu horóscopo de hoje? Sou de peixes"
}]

client_openai = OpenAI(api_key=openai_api_key)

response = client_openai.responses.create(
    model="gpt-4.1-mini",
    input=input_list,
    temperature=0.0, 
    tools=functions
)

tool_call = response.output[0]
tool_call
# Out:
# ResponseFunctionToolCall(arguments='{"signo":"Peixes"}', call_id='call_8LMBcBBNncvvXS4XTT6hFtMx', name='get_horoscope', type='function_call', id='fc_0c1855acd3894b3b0069739c4e00888193a4531018b94cbc75', status='completed')

# %%
argumento = tool_call.arguments
argumento
# Out:
# '{"signo":"Peixes"}'

# %%
arg = json.loads(argumento)
arg["signo"]
# Out:
# 'Peixes'

# %%
tool_name = tool_call.name
tool_name
# Out:
# 'get_horoscope'

# %%
if tool_name == "get_horoscope":
    tool_result = get_horoscope(arg["signo"])

# %% [markdown]
# ### 2ª chamada -> LLM gera resposta:

# %%
# Recria o contexto: pergunta original + resultado da tool (como mensagem "user")
followup_input = [
    {"role": "user", "content": "Qual o meu horóscopo de hoje? Sou de peixes"},
    {
        "role": "user",
        "content": f"[{tool_name} result]\n{tool_result}"
    }
]

# %%
followup = client_openai.responses.create(
        model="gpt-4.1-mini",
        input=followup_input,
        temperature=0.0
    )

followup
# Out:
# Response(id='resp_0e128d13db530edb0069739cdaae6c819091078c8f89ed38bd', created_at=1769184474.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-mini-2025-04-14', object='response', output=[ResponseOutputMessage(id='msg_0e128d13db530edb0069739cdb01dc8190aa83ac79b75434d8', content=[ResponseOutputText(annotations=[], text='Seu horóscopo de hoje para Peixes indica que na próxima sexta-feira você terá uma viagem para São Paulo. Pode ser um momento interessante para novas experiências e oportunidades. Aproveite para se preparar e ficar aberto a novidades! Se quiser, posso ajudar com dicas para a viagem ou algo mais.', type='output_text', logprobs=[])], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=0.0, tool_choice='auto', tools=[], top_p=1.0, background=False, completed_at=1769184475.0, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort=None, generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=43, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=61, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=104), user=None, billing={'payer': 'developer'}, frequency_penalty=0.0, presence_penalty=0.0, store=True)

# %%
followup.output[0].content[0].text
# Out:
# 'Seu horóscopo de hoje para Peixes indica que na próxima sexta-feira você terá uma viagem para São Paulo. Pode ser um momento interessante para novas experiências e oportunidades. Aproveite para se preparar e ficar aberto a novidades! Se quiser, posso ajudar com dicas para a viagem ou algo mais.'

# %% [markdown]
# ## Muito manual né, vamos tentar automatizar isso
#
# **Observação: O exemplo abaixo não roda em produção**

# %%
def run_with_tools_simple(content:str ,tools=functions, model="gpt-4.1-mini"):
    client = OpenAI(api_key=openai_api_key)

    input_list = [{
    "role": "user",
    "content": content
    }]
    
    response = client.responses.create(
        model=model,
        input=input_list,
        tools=tools,
        temperature=0
    )

    while response.output[0].type == "function_call":
        tool_call = response.output[0]
        args = json.loads(tool_call.arguments)

        if tool_call.name == "get_horoscope":
            result = get_horoscope(**args)
        elif tool_call.name == "get_weather":
            result = get_weather(**args)
        else:
            raise ValueError("Tool desconhecida")

        input_list.append({
            "role": "user",
            "content": f"[{tool_call.name} result]\n{result}"
        })

        response = client.responses.create(
            model=model,
            input=input_list,
            temperature=0
        )

    return response.output[0].content[0].text

# %%
run_with_tools_simple("Qual o clima de hoje em Botswana?")
# Out:
# chamando a função get_weather
# 'O clima de hoje em Botswana, na região de Gaborone, está com nuvens dispersas.'
